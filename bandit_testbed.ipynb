# %%
from bandit_testbed import *
import scipy

# %%
algos = {'greedy_1': GreedyBandit(k_arms=10)}
testbed = KArmedBanditTestbed(k_arms=10,
                             time_steps=1000,
                             episodes=2000,
                             algorithms=algos)

# %%
results = testbed.run()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.DataFrame(results['greedy_1']).mean().plot(figsize=(10, 5))
plt.ylim([0, 1.5])
plt.yticks([0, 0.5, 1, 1.5])
plt.xticks([1, 250, 500, 750, 1000])
# Out:
# ([<matplotlib.axis.XTick at 0x7f83064f7d50>,
# ...
#  [Text(1, 0, '1'),
#   Text(250, 0, '250'),
#   Text(500, 0, '500'),
#   Text(750, 0, '750'),
#   Text(1000, 0, '1000')])
